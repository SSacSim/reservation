# %%
from telegram import Update
from telegram.ext import ApplicationBuilder, CommandHandler, MessageHandler, filters, ContextTypes

async def start(update: Update, context: ContextTypes.DEFAULT_TYPE):
    await update.message.reply_text(f"안녕하세요! 메시지를 보내주세요.")

async def echo(update: Update, context: ContextTypes.DEFAULT_TYPE):
    user_text = update.message.text
    print("사용자가 보낸 메시지:", user_text)
    await update.message.reply_text(f"받은 메시지: {user_text}")

if __name__ == "__main__":
    token = "8305150892:AAGRgaCdiw5l_Dr2tPVztQceleepBswrEc8"
    app = ApplicationBuilder().token(token).build()

    app.add_handler(CommandHandler("start", start))
    app.add_handler(MessageHandler(filters.TEXT & (~filters.COMMAND), echo))

    print("텔레그램 봇 시작")
    app.run_polling()
# Out:
# 텔레그램 봇 시작
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/venv/lib/python3.14/site-packages/telegram/ext/_application.py:1054, in Application.__run(self, updater_coroutine, stop_signals, bootstrap_retries, close_loop)
#    1053 try:
# -> 1054     loop.run_until_complete(self._bootstrap_initialize(max_retries=bootstrap_retries))
#    1055     if self.post_init:
#
# File /usr/lib/python3.14/asyncio/base_events.py:695, in BaseEventLoop.run_until_complete(self, future)
#     694 self._check_closed()
# --> 695 self._check_running()
#     697 new_task = not futures.isfuture(future)
#
# File /usr/lib/python3.14/asyncio/base_events.py:631, in BaseEventLoop._check_running(self)
#     630 if self.is_running():
# --> 631     raise RuntimeError('This event loop is already running')
#     632 if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/venv/lib/python3.14/site-packages/telegram/ext/_application.py:1079, in Application.__run(self, updater_coroutine, stop_signals, bootstrap_retries, close_loop)
#    1078         loop.run_until_complete(self.post_stop(self))
# -> 1079 loop.run_until_complete(self.shutdown())
#    1080 if self.post_shutdown:
#
# File /usr/lib/python3.14/asyncio/base_events.py:695, in BaseEventLoop.run_until_complete(self, future)
#     694 self._check_closed()
# --> 695 self._check_running()
#     697 new_task = not futures.isfuture(future)
#
# File /usr/lib/python3.14/asyncio/base_events.py:631, in BaseEventLoop._check_running(self)
#     630 if self.is_running():
# --> 631     raise RuntimeError('This event loop is already running')
#     632 if events._get_running_loop() is not None:
#
# RuntimeError: This event loop is already running
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 20
#      17 app.add_handler(MessageHandler(filters.TEXT & (~filters.COMMAND), echo))
#      19 print("텔레그램 봇 시작")
# ---> 20 app.run_polling()
#
# File ~/venv/lib/python3.14/site-packages/telegram/ext/_application.py:839, in Application.run_polling(self, poll_interval, timeout, bootstrap_retries, allowed_updates, drop_pending_updates, close_loop, stop_signals)
#     836 def error_callback(exc: TelegramError) -> None:
#     837     self.create_task(self.process_error(error=exc, update=None))
# --> 839 return self.__run(
#     840     updater_coroutine=self.updater.start_polling(
#     841         poll_interval=poll_interval,
#     842         timeout=timeout,
#     843         bootstrap_retries=bootstrap_retries,
#     844         allowed_updates=allowed_updates,
#     845         drop_pending_updates=drop_pending_updates,
#     846         error_callback=error_callback,  # if there is an error in fetching updates
#     847     ),
#     848     stop_signals=stop_signals,
#     849     bootstrap_retries=bootstrap_retries,
#     850     close_loop=close_loop,
#     851 )
#
# File ~/venv/lib/python3.14/site-packages/telegram/ext/_application.py:1084, in Application.__run(self, updater_coroutine, stop_signals, bootstrap_retries, close_loop)
#    1082 finally:
#    1083     if close_loop:
# -> 1084         loop.close()
#
# File /usr/lib/python3.14/asyncio/unix_events.py:70, in _UnixSelectorEventLoop.close(self)
#      69 def close(self):
# ---> 70     super().close()
#      71     if not sys.is_finalizing():
#      72         for sig in list(self._signal_handlers):
#
# File /usr/lib/python3.14/asyncio/selector_events.py:101, in BaseSelectorEventLoop.close(self)
#      99 def close(self):
#     100     if self.is_running():
# --> 101         raise RuntimeError("Cannot close a running event loop")
#     102     if self.is_closed():
#     103         return
#
# RuntimeError: Cannot close a running event loop

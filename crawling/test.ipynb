# %%
import sys
import os

# main.py 기준 telegram_util 폴더 경로
sys.path.append(os.path.abspath(".."))  # .. = project 루트 폴더


# from telegram_util import telegram_utils
from telegram_util import telegram_utils

# telegram_utils.send_message('ddd')

# %%
telegram_utils.send_message('ddd')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 telegram_utils.send_message('ddd')
#
# File /mnt/telegram_util/telegram_utils.py:15, in send_message(text)
#      13 bot = Bot(token=TOKEN)
#      14 chat_id = userInfo["telegramChatid"]
# ---> 15 asyncio.run(bot.send_message(chat_id=chat_id, text="안녕하세요! 파이썬에서 보낸 메시지입니다.33"))
#
# File /usr/lib/python3.14/asyncio/runners.py:200, in run(main, debug, loop_factory)
#     170 """Execute the coroutine and return the result.
#     171
#     172 This function runs the passed coroutine, taking care of
#    (...)    196     asyncio.run(main())
#     197 """
#     198 if events._get_running_loop() is not None:
#     199     # fail fast with short traceback
# --> 200     raise RuntimeError(
#     201         "asyncio.run() cannot be called from a running event loop")
# ...
